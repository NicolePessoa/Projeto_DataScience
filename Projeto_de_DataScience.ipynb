# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolePessoa/Projeto_DataScience/blob/main/Projeto_de_DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Análise das Notas em Geral**

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuariosID","Filmes", "Notas","Momentos"]
notas.head()
# Out:
#    usuariosID  Filmes  Notas   Momentos
# 0           1       1    4.0  964982703
# 1           1       3    4.0  964981247
# 2           1       6    4.0  964982224
# 3           1      47    5.0  964983815
# 4           1      50    5.0  964982931

# %%
notas['Notas'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['Notas'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: Notas, dtype: int64

# %%
notas.Notas.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: Notas, dtype: float64

# %%
notas.Notas.plot()
# Out:
# <Axes: >

# %%
notas.Notas.plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas.Notas.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: Notas, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.Notas)
# Out:
# <Axes: >

# %% [markdown]
# #**Visualizando os Filmes**

# %%
filmes = pd.read_csv("movies.csv")
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.columns = ["filmeId","titulo","generos"]
filmes
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuariosID  Filmes  Notas   Momentos
# 0           1       1    4.0  964982703
# 1           1       3    4.0  964981247
# 2           1       6    4.0  964982224
# 3           1      47    5.0  964983815
# 4           1      50    5.0  964982931

# %%
notas.query("Filmes==1")
# Out:
#        usuariosID  Filmes  Notas    Momentos
# 0               1       1    4.0   964982703
# 516             5       1    4.0   847434962
# 874             7       1    4.5  1106635946
# 1434           15       1    2.5  1510577970
# 1667           17       1    4.5  1305696483
# ...           ...     ...    ...         ...
# 97364         606       1    2.5  1349082950
# 98479         607       1    4.0   964744033
# 98666         608       1    2.5  1117408267
# 99497         609       1    3.0   847221025
# 99534         610       1    5.0  1479542900
#
# [215 rows x 4 columns]

# %% [markdown]
# #**Análise de Notas de Filmes Especificos**

# %%
notas.query("Filmes==1").Notas.mean()
# Out:
# 3.9209302325581397

# %%
notas.query("Filmes==2").Notas.mean()
# Out:
# 3.4318181818181817

# %%
notas.groupby("Filmes")

# %%
notas.groupby("Filmes").mean()
# Out:
#         usuariosID     Notas      Momentos
# Filmes
# 1       306.530233  3.920930  1.129835e+09
# 2       329.554545  3.431818  1.135805e+09
# 3       283.596154  3.259615  1.005110e+09
# 4       219.857143  2.357143  8.985789e+08
# 5       299.571429  3.071429  9.926643e+08
# ...            ...       ...           ...
# 193581  184.000000  4.000000  1.537109e+09
# 193583  184.000000  3.500000  1.537110e+09
# 193585  184.000000  3.500000  1.537110e+09
# 193587  184.000000  3.500000  1.537110e+09
# 193609  331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
notas.groupby("Filmes").mean()["Notas"]
# Out:
# Filmes
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: Notas, Length: 9724, dtype: float64

# %%
medias_por_filmes = notas.groupby("Filmes").mean()["Notas"]
medias_por_filmes.head()
# Out:
# Filmes
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: Notas, dtype: float64

# %%
medias_por_filmes.plot()
# Out:
# <Axes: xlabel='Filmes'>

# %%
medias_por_filmes.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
medias_por_filmes.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: Notas, dtype: float64

# %%
sns.distplot(medias_por_filmes)
# Out:
# <ipython-input-67-abd4358e7796>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias_por_filmes)
# <Axes: xlabel='Notas', ylabel='Density'>

# %%
sns.distplot(medias_por_filmes, bins=10)
# Out:
# <ipython-input-69-e48272697456>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias_por_filmes, bins=10)
# <Axes: xlabel='Notas', ylabel='Density'>

# %%
sns.displot(medias_por_filmes)

# %% [markdown]
# #**Análise com Matplot**

# %%
import matplotlib.pyplot as plt
plt.hist(medias_por_filmes)
plt.title("Histograma das médias dos Filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos Filmes')

# %%
plt.figure(figsize=(6,8))
sns.boxplot(y=medias_por_filmes)
# Out:
# <Axes: ylabel='Notas'>

# %% [markdown]
# #**Análise de um Novo Arquivo de Filmes**

# %%
tmbd = pd.read_csv("tmdb_5000_movies.csv")
tmbd.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmbd.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)
